# %%
import pandas as pd

# %%
data = pd.read_excel('./files/sample_1.xlsx',header = 1,skipfooter = 2,usecols = "A:C")
data
# Out:
#   국적코드  성별    입국객수
# 0  A01  남성  106320
# 1  A01  여성  191436
# 2  A31  남성     319
# 3  A31  여성      42
# 4  A18  남성  158912
# 5  A18  여성  232943

# %%
data.head(3)
# Out:
#   국적코드  성별    입국객수
# 0  A01  남성  106320
# 1  A01  여성  191436
# 2  A31  남성     319

# %%
data.tail(5)
# Out:
#   국적코드  성별    입국객수
# 1  A01  여성  191436
# 2  A31  남성     319
# 3  A31  여성      42
# 4  A18  남성  158912
# 5  A18  여성  232943

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적코드    6 non-null      object
#  1   성별      6 non-null      object
#  2   입국객수    6 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes

# %%
data['국적코드']
# Out:
# 0    A01
# 1    A01
# 2    A31
# 3    A31
# 4    A18
# 5    A18
# Name: 국적코드, dtype: object

# %%
data['기준년월'] = "2019-11"
data
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 1  A01  여성  191436  2019-11
# 2  A31  남성     319  2019-11
# 3  A31  여성      42  2019-11
# 4  A18  남성  158912  2019-11
# 5  A18  여성  232943  2019-11

# %%
data[data['성별']=='남성']
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 2  A31  남성     319  2019-11
# 4  A18  남성  158912  2019-11

# %%
data[(data['성별']=='여성') &
     (data['입국객수']>= 150000)]
# Out:
#   국적코드  성별    입국객수     기준년월
# 1  A01  여성  191436  2019-11
# 5  A18  여성  232943  2019-11

# %%
data[(data['국적코드']=='A01') | (data['국적코드'] =='A18')]
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 1  A01  여성  191436  2019-11
# 4  A18  남성  158912  2019-11
# 5  A18  여성  232943  2019-11

# %%
data[data['국적코드'].isin(['A18','A01'])==False]
# Out:
#   국적코드  성별  입국객수     기준년월
# 2  A31  남성   319  2019-11
# 3  A31  여성    42  2019-11

# %%
##국적코드표 데이터 읽어 들이기
sample_code = pd.read_excel('./files/sample_codemaster.xlsx')
sample_code
# Out:
#   국적코드     국적명
# 0  A01      일본
# 1  A02      대만
# 2  A03      홍콩
# 3  A18      중국
# 4  A19      이란
# 5  A22  우즈베키스탄
# 6  A23   카자흐스탄
# 7  A99  아시아 기타

# %%
data.merge(sample_code)
# Out:
#   국적코드  성별    입국객수     기준년월 국적명
# 0  A01  남성  106320  2019-11  일본
# 1  A01  여성  191436  2019-11  일본
# 2  A18  남성  158912  2019-11  중국
# 3  A18  여성  232943  2019-11  중국

# %%
# pd.merge(left = data,
#         right=sample_code,
#         how = "outer",
#         left_on = "국적코드",
#         right_on = "국적코드")
data.merge(sample_code, how='outer')
# Out:
#    국적코드   성별      입국객수     기준년월     국적명
# 0   A01   남성  106320.0  2019-11      일본
# 1   A01   여성  191436.0  2019-11      일본
# 2   A31   남성     319.0  2019-11     NaN
# 3   A31   여성      42.0  2019-11     NaN
# 4   A18   남성  158912.0  2019-11      중국
# 5   A18   여성  232943.0  2019-11      중국
# 6   A02  NaN       NaN      NaN      대만
# 7   A03  NaN       NaN      NaN      홍콩
# 8   A19  NaN       NaN      NaN      이란
# 9   A22  NaN       NaN      NaN  우즈베키스탄
# 10  A23  NaN       NaN      NaN   카자흐스탄
# 11  A99  NaN       NaN      NaN  아시아 기타

# %%
sample_2 = pd.read_excel('./files/sample_2.xlsx',header = 1,skipfooter=2,usecols='A:C')
sample_2
# Out:
#   국적코드  성별    입국객수
# 0  A01  남성   92556
# 1  A01  여성  163737
# 2  A18  남성  155540
# 3  A18  여성  249023

# %%
sample_2['기준년월'] ='2019-12'
sample_2
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성   92556  2019-12
# 1  A01  여성  163737  2019-12
# 2  A18  남성  155540  2019-12
# 3  A18  여성  249023  2019-12

# %%
df = data.merge(sample_2,how = 'outer')
##== data.concat(sample_2)

# %%
df.to_excel('./files/sample_total.xlsx', index=False)
