# %%
import numpy as np

# %%
import pandas as pd

# %%
#NaN = 표시하지 않는 값

print(np.NaN== True )
print(np.NaN== False)
print(np.NaN== 0)
print(np.NaN== '')

print(np.NaN==np.NaN )
print(np.nan== np.nan )
print(np.NaN== np.NAN )
print(np.nan== np.NAN)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False

# %%
#null =없는 값
print(pd.isnull(np.NaN))

print(pd.notnull(np.NaN))
# Out:
# True
# False

# %%
vs= visited.merge(survey,left_don='ident',right_on='taken')
print(vs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\STUDY\StudyPython22\pandas\[05]판다스 누락값 처리하기.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/pandas/%5B05%5D%ED%8C%90%EB%8B%A4%EC%8A%A4%20%EB%88%84%EB%9D%BD%EA%B0%92%20%EC%B2%98%EB%A6%AC%ED%95%98%EA%B8%B0.ipynb#ch0000004?line=0'>1</a> vs= visited.merge(survey,left_don='ident',right_on='taken')
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/pandas/%5B05%5D%ED%8C%90%EB%8B%A4%EC%8A%A4%20%EB%88%84%EB%9D%BD%EA%B0%92%20%EC%B2%98%EB%A6%AC%ED%95%98%EA%B8%B0.ipynb#ch0000004?line=1'>2</a> print(vs)
#
# NameError: name 'visited' is not defined

# %%
num_legs = pd.Series({'gooat':4, 'amoeba':nan})
print(num_legs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\STUDY\StudyPython22\pandas\[05]판다스 누락값 처리하기.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/pandas/%5B05%5D%ED%8C%90%EB%8B%A4%EC%8A%A4%20%EB%88%84%EB%9D%BD%EA%B0%92%20%EC%B2%98%EB%A6%AC%ED%95%98%EA%B8%B0.ipynb#ch0000005?line=0'>1</a> num_legs = pd.Series({'gooat':4, 'amoeba':nan})
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/pandas/%5B05%5D%ED%8C%90%EB%8B%A4%EC%8A%A4%20%EB%88%84%EB%9D%BD%EA%B0%92%20%EC%B2%98%EB%A6%AC%ED%95%98%EA%B8%B0.ipynb#ch0000005?line=1'>2</a> print(num_legs)
#
# NameError: name 'nan' is not defined

# %%
scientists = pd.DataFrame({
    'Name' : ['Rosaline Franklin', 'William Geosset'],
    'Occupation' : ['Chemist', ' Statistician'],
    'Born':['1920-07-25','1876-06-13'],
    'missing':[NaN, nan]})

print(scientists)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\STUDY\StudyPython22\pandas\[05]판다스 누락값 처리하기.ipynb Cell 7' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/pandas/%5B05%5D%ED%8C%90%EB%8B%A4%EC%8A%A4%20%EB%88%84%EB%9D%BD%EA%B0%92%20%EC%B2%98%EB%A6%AC%ED%95%98%EA%B8%B0.ipynb#ch0000006?line=0'>1</a> scientists = pd.DataFrame({
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/pandas/%5B05%5D%ED%8C%90%EB%8B%A4%EC%8A%A4%20%EB%88%84%EB%9D%BD%EA%B0%92%20%EC%B2%98%EB%A6%AC%ED%95%98%EA%B8%B0.ipynb#ch0000006?line=1'>2</a>     'Name' : ['Rosaline Franklin', 'William Geosset'],
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/pandas/%5B05%5D%ED%8C%90%EB%8B%A4%EC%8A%A4%20%EB%88%84%EB%9D%BD%EA%B0%92%20%EC%B2%98%EB%A6%AC%ED%95%98%EA%B8%B0.ipynb#ch0000006?line=2'>3</a>     'Occupation' : ['Chemist', ' Statistician'],
# ...

# %%
scientists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes

# %%
ebola = pd.read_csv('./country_timeseries.csv')
print(ebola)
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
num_row = ebola.shape[0]
num_missing = num_row - ebola.count()
print(num_missing)
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
# count_nonzero() = 배열에서 0이 아닌 값의 개수 확인
print(np.count_nonzero(ebola.isnull()))
print(np.count_nonzero(ebola['Cases_Guinea'].isnull()))
# Out:
# 1214
# 29

# %%
#value_counts() : 지정한 열의 빈도 확인
print(ebola['Cases_Guinea'].value_counts(dropna =False))
# Out:
# NaN       29
# 86.0       3
# 495.0      2
# 112.0      2
# 390.0      2
#           ..
# 1199.0     1
# 1298.0     1
# 1350.0     1
# 1472.0     1
# 49.0       1
# Name: Cases_Guinea, Length: 89, dtype: int64

# %%
##누락값 처리
#누락값 변경 - fill_na()

ebola.iloc[:,:5].head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0

# %%
ebola.fillna(0).iloc[:,:5].head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0            0.0            10030.0
# 1    1/4/2015  288        2775.0            0.0             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           0.0         8157.0                0.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0

# %%
ebola.fillna(method = 'ffill').iloc[0:5, 0:5]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2769.0         8157.0             9722.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0

# %%
#bfill = 뒤에 있는 값을 들고와서 채워넣음
ebola.fillna(method = 'bfill').iloc[0:5, 0:5]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0         8166.0            10030.0
# 1    1/4/2015  288        2775.0         8166.0             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2730.0         8157.0             9633.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0

# %%
##결측값 양쪽의 두개의 중간값구한 다음 누락값을 처리함
ebola.interpolate().iloc[0:5, 0:5]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2749.5         8157.0             9677.5
# 4  12/31/2014  284        2730.0         8115.0             9633.0

# %%
ebola.interpolate()
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2749.5         8157.0             9677.5
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            8.0                6.0
# 119   3/25/2014    3          86.0            8.0                6.0
# 120   3/24/2014    2          86.0            8.0                6.0
# 121   3/22/2014    0          49.0            8.0                6.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
#결측값이 있는 행 없애고 출력
print(ebola.shape)
ebola_dropna = ebola.dropna()
print(ebola_dropna.shape)
print(ebola_dropna.iloc[0:5, 0:5])
# Out:
# (122, 18)
# (1, 18)
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 19  11/18/2014  241        2047.0         7082.0             6190.0

# %%
#inplace = inplace쓰기 전 생각해보기 값이 완전 변해버려서 바꾸려면 다시 처음부터 불러와야함
ebola.fillna(method = 'ffill',inplace = True)

# %%
ebola = pd.read_csv('.//country_timeseries.csv')
