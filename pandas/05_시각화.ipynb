# %%
import pandas as pd

# %%
df = pd.read_excel('./files/kto_total.xlsx')
df
# Out:
#             국적      관광    상용   공용  유학/연수     기타       계     기준년월     대륙  \
# 0           일본  202825  1750   89    549   3971  209184  2010-01    아시아
# 1           대만   35788    41   17     37    516   36399  2010-01    아시아
# 2           홍콩   13874    55    0     21    595   14545  2010-01    아시아
# 3          마카오     554     0    0      0      0     554  2010-01    아시아
# 4           태국   13374    39   13     53   4335   17814  2010-01    아시아
# ...        ...     ...   ...  ...    ...    ...     ...      ...    ...
# 6955    대양주 기타     519     1    6      9     74     609  2019-08  오세아니아
# 6956  남아프리카공화국     634     6    1     11   1235    1887  2019-08   아프리카
# 6957   아프리카 기타    2081   593  165    841   1184    4864  2019-08   아프리카
# 6958      국적미상      36     1    0      8     12      57  2019-08   기타대륙
# 6959        교포       0     0    0      0  16560   16560  2019-08     교포
#
#       관광객비율(%)  전체비율(%)
# 0         97.0     50.6
# 1         98.3      8.9
# 2         95.4      3.5
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform

if platform.system() =='Windows':
    path = 'c:/Windows/Fonts/Malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family = font_name)


elif platform.system() == "Darwin" :
    rc("font", family ='AppleGothic')
else:
    print("Check your OS System...")

# %%
condition = (df['국적'] == '중국')

condition
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6955    False
# 6956    False
# 6957    False
# 6958    False
# 6959    False
# Name: 국적, Length: 6960, dtype: bool

# %%
df_fillter = df[condition]
df_fillter
# Out:
#       국적      관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17    중국   40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77    중국   60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137   중국   50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197   중국   84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257   중국   89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
# ...   ..     ...    ...  ...    ...    ...     ...      ...  ...       ...
# 6677  중국  410542   3575  362   9959  68812  493250  2019-04  아시아      83.2
# 6737  중국  413949   4034  534  14003  67893  500413  2019-05  아시아      82.7
# 6797  중국  395196   3743  399  14680  60989  475007  2019-06  아시아      83.2
# 6857  중국  439699   3587  356  10847  64643  519132  2019-07  아시아      84.7
# 6917  중국  451570   3625  388  44291  78238  578112  2019-08  아시아      78.1
#
#       전체비율(%)
# 17       10.1
# 77       13.6
# 137       9.2
# ...

# %%
plt.plot(df_fillter['기준년월'], df_fillter['관광'])

# %%
plt.figure(figsize=(12,4))##높이,넓이
plt.plot(df_fillter['기준년월'], df_fillter['관광'])#x축,y축
plt.title('중국 국적의 년월별 관광객 추이')

plt.xlabel('기준년월')
plt.ylabel('관광객수')

plt.xticks(["2010-01","2011-01","2012-01","2013-01","2014-01","2015-01","2016-01","2017-01","2018-01","2019-01"])
# 그래프 크기 조정
# plt.figure(figsize = (12,4))

# # 데이터 넣기
# plt.plot(df_fillter["기준년월"], df_fillter["관광"])

# # 그래프 전체 제목 넣기
# plt.title("중국 국적의 년월별 관광객 추이")

# # x축, y축 이름 달기
# plt.xlabel("기준년월")
# plt.ylabel("관광객수")

# # x축의 눈금 값 설정하기
# plt.xticks(["2010-01", "2011-01", "2012-01", "2013-01", "2014-01", 
#             "2015-01", "2016-01", "2017-01", "2018-01", "2019-01"])


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\STUDY\StudyPython22\new_jupyter\days3_전처리\1_시각화.ipynb Cell 7' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000006?line=4'>5</a> plt.xlabel('기준년월')
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000006?line=5'>6</a> plt.ylabel('관광객수')
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000006?line=7'>8</a> plt.xticks(int(["2010-01","2011-01","2012-01","2013-01","2014-01","2015-01","2016-01","2017-01","2018-01","2019-01"]))
# ...

# %%
df.sort_values(by = '전체비율(%)', ascending = False).head()
# Out:
#       Unnamed: 0  국적      관광    상용   공용  유학/연수      기타       계    기준년월   대륙  \
# 4697        4697  중국  823016  4103  354   7122   82924  917519  201607  아시아
# 4757        4757  중국  747818  4352  270  35523   85808  873771  201608  아시아
# 120          120  일본  299820  1483  124    519    4180  306126  201003  아시아
# 3317        3317  중국  588181  8340  173  23091  137898  757683  201408  아시아
# 4337        4337  중국  456636  3723  140   4383   57099  521981  201601  아시아
#
#       관광객비율(%)  전체비율(%)
# 4697      89.7     58.6
# 4757      85.6     57.0
# 120       97.9     55.0
# 3317      77.6     54.3
# 4337      87.5     52.8

# %%
temp=pd.pivot_table(df, values='전체비율(%)', index= '국적',aggfunc='mean').sort_values('전체비율(%)', ascending =False).head()
temp
# Out:
#       전체비율(%)
# 국적
# 중국  32.116379
# 일본  28.350000
# 대만   6.650000
# 미국   6.039655
# 홍콩   4.645690

# %%
temp.reset_index(inplace = True)
temp
# Out:
#    국적    전체비율(%)
# 0  중국  32.116379
# 1  일본  28.350000
# 2  대만   6.650000
# 3  미국   6.039655
# 4  홍콩   4.645690

# %%
cntry_list = temp['국적']
cntry_list
# Out:
# 0    중국
# 1    일본
# 2    대만
# 3    미국
# 4    홍콩
# Name: 국적, dtype: object

# %%
for cntry in cntry_list:
    condition = (df['국적'] == cntry)
    df_fillter = df[condition]

    plt.figure(figsize=(12,4))##높이,넓이
    plt.plot(df_fillter['기준년월'], df_fillter['관광'])#x축,y축
    plt.title('중국 국적의 년월별 관광객 추이')

    plt.xlabel('기준년월')
    plt.ylabel('관광객수')

    plt.xticks(["2010-01" , "2011-01" , "2012-01" , "2013-01" , "2014-01",
                "2015-01" , "2016-01" , "2017-01" , "2018-01" , "2019-01"])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\STUDY\StudyPython22\new_jupyter\days3_전처리\1_시각화.ipynb Cell 12' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000011?line=8'>9</a> plt.xlabel('기준년월')
#      <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000011?line=9'>10</a> plt.ylabel('관광객수')
# ---> <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000011?line=11'>12</a> plt.xticks(["2010-01" , "2011-01" , "2012-01" , "2013-01" , "2014-01",
# ...

# %%
# 히트맵 그리기 
#df2 = df 이러면 주소만 복사되고 내용 복사가 안된다 그래서 완전한 복사하려면 .copy를 하면된다.
df2 = df.copy()
df2
# Out:
#       Unnamed: 0        국적      관광    상용   공용  유학/연수     기타       계    기준년월  \
# 0              0        일본  202825  1750   89    549   3971  209184  201001
# 1              1        대만   35788    41   17     37    516   36399  201001
# 2              2        홍콩   13874    55    0     21    595   14545  201001
# 3              3       마카오     554     0    0      0      0     554  201001
# 4              4        태국   13374    39   13     53   4335   17814  201001
# ...          ...       ...     ...   ...  ...    ...    ...     ...     ...
# 6955        6955    대양주 기타     519     1    6      9     74     609  201908
# 6956        6956  남아프리카공화국     634     6    1     11   1235    1887  201908
# 6957        6957   아프리카 기타    2081   593  165    841   1184    4864  201908
# 6958        6958      국적미상      36     1    0      8     12      57  201908
# 6959        6959        교포       0     0    0      0  16560   16560  201908
#
#          대륙  관광객비율(%)  전체비율(%)
# ...

# %%
#df2 의 기준년월 데이터에서 년도만 추출하여'년도'칼럼 만들기
#df2 의 기준년월 데이터에서 월만 추출하여'월'칼럼 만들기
df2['기준년월'].str[0 : 4]
df['년도'] = df2['기준년월'].str.slice(0,4)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\STUDY\StudyPython22\new_jupyter\days3_전처리\1_시각화.ipynb Cell 14' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000014?line=0'>1</a> #df2 의 기준년월 데이터에서 년도만 추출하여'년도'칼럼 만들기
#       <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000014?line=1'>2</a> #df2 의 기준년월 데이터에서 월만 추출하여'월'칼럼 만들기
# ----> <a href='vscode-notebook-cell:/c%3A/STUDY/StudyPython22/new_jupyter/days3_%EC%A0%84%EC%B2%98%EB%A6%AC/1_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#ch0000014?line=2'>3</a> df2['기준년월'].str[0 : 4]
# ...

# %%
df['월'] = df['기준년월'].str.slice(5,7)

# %%
condition['국가'] ==['중국']

# %%
df_fillter = df[condition]

# %%
#년도 및 월별 관광 데이터의 평균 조회
df_pivot = pd.pivot_table(df,values='관광',index = '년도',columns='월')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (16,10))
sns.heatmap(df_pivot, annot= True, fmt ='.0f', cmap='rocket_r')

plt.title('년도 및 월별 중국 관광객 추이(히트맵)')
plt.show()

# %%
#(트랜드) 2010년부터 2018년까지 관광객수가 꾸준히 증가하고 있으며, 
#   계절적인 영향을 많이 받는것으로 보임

#(이벤트)2015년 68월 중에 관광객수가 급격히 감소 했음
#   -원인분석 : 메르스 전염병에 의한 일시적 감소를 보였으며, 이후 증가됨
#       중국의 경우 2017년 3월부터 관광객수가 급격히 감소 했음
#   -원인분석: 우리나라 정부의 사드 미사일 기지 설치에 따른 보복으로
#       급격히 감소했으며, 매우 미미하게 관광객이 증가하고 있음,

#(계절) 2010년부터 4월8월 사이에 국내 관광객이 많으며,
#    2016년 이후 봄, 여름에 매우 많은 관광개과, 가을에 매우 많은 관광객이 찾고있음
